# %% [markdown]
# # Verify merge

# %%
from mfreight.Multimodal.merge_graphs import MergeNets
from mfreight.Multimodal.graph_utils import MultimodalNet
from mfreight.utils import folium_revisited

import osmnx as ox
import networkx as nx
import numpy as np
import time

# %%
start = time.time()
total = MergeNets()
total.merge_networks()
print(f'elapsed time: {time.time()-start}')
# Out:
# elapsed time: 3.283414125442505

# %%
Net= MultimodalNet()
Net.plot_multimodal_graph()

# %%
hwy_dest = (25.382380, -80.475159)
hwy_ori =(30.439440, -85.057166)
df, count = MultimodalNet().get_route_detail((30.439440, -85.057166),(25.382380, -80.475159),'CO2_eq_kg')

# %%
node_orig,node_dest = 1000001567, 1000006518
shortest_path_nodes = nx.dijkstra_path(
    Net.G_multimodal_u, node_orig, node_dest, weight='length'
)
ox.plot_route_folium(Net.G_multimodal_u,
                                shortest_path_nodes,route_width=4,route_color="green")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
from mfreight.Multimodal.graph_utils import MultimodalNet
Net = MultimodalNet()
Net.plot_route(hwy_dest,hwy_ori,folium=True)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
a = {'a':12,'b':1223,'c':22}
for i in a:
    print(a[i])
# Out:
# 12
# 1223
# 22

# %%
e = ox.graph_to_gdfs(Net.G_multimodal_u, nodes=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-3304db75a7b6> in <module>
#       1 e = ox.graph_to_gdfs(Net.G_multimodal_u, nodes=False)
# ----> 2 pd.unique(e.trans_mode)
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
pd.unique(e.trans_mode)
# Out:
# array(['road', 'intermodal_link', 'rail'], dtype=object)

# %%
# Example array
import numpy as np
X = np.array([1,2,3])

def feature_scaling(X):
    means = X.mean(axis =0)
    stds = X.std(axis= 0, ddof=1)
    X = (X - min(X)) / (max(X) - min(X))
    return X

# %%
feature_scaling(X)
# Out:
# array([0. , 0.5, 1. ])

# %%
import pandas as pd
a = pd.DataFrame({'one':[1,2,3,4],'two':[121341,12342,33322,2222]})

# %%
a['one_n'] = feature_scaling(a.one.values)
a['one_n'] = feature_scaling(a.one.values)
a
# Out:
#    one     two     one_n
# 0    1  121341  0.000000
# 1    2   12342  0.333333
# 2    3   33322  0.666667
# 3    4    2222  1.000000

# %%
import osmnx as ox

# %%
Net = MultimodalNet()
no, ed = ox.graph_to_gdfs(Net.G_multimodal_u)
Net.normalize_features(ed)
# Out:
# <class 'networkx.classes.multigraph.MultiGraph'>

# %%
features_weight: dict = {"length":0.33, "CO2_eq_kg":0.33, "duration_h":0.33}

# %%
features_weight.length
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-c5945274730c> in <module>
# ----> 1 features_weight.length
#
# AttributeError: 'dict' object has no attribute 'length'

# %%
features_weight['length']
# Out:
# 0.33

# %%
**features_weight
# Out:
#   File "<ipython-input-25-f55368da1c8e>", line 1
#     **features_weight
#      ^
# SyntaxError: invalid syntax

# %%
import re
select_arrival = '(122.3211,113.223)'
arrival_x = float(re.findall(r'(-?\d+.\d+)\)',select_arrival)[0])

# %%
arrival_x
# Out:
# 113.223
