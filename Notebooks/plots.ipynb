# %% [markdown]
# # Plot of the multimodal network

# %%
import time
import osmnx as ox

import sys
sys.path.append('../../Multimodal_freight_USA/')
from mfreight.Multimodal.graph_utils import MultimodalNet

# %%
Net.plot_multimodal_graph()
# Out:
# [300535, 300539, 300542, 300545, 300549]
